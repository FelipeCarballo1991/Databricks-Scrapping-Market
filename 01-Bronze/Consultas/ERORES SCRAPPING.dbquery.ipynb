-- %%
select * from `supermercadoetl_prod`.`audit`.scraping_errors;


SELECT * from supermercadoetl_dev.bronze.precios_scraping
WHERE nombre = "Vacio Estancia";

SELECT * from supermercadoetl_prod.silver.precios_productos
WHERE fecha_extraccion = "2026-04-15" 
-- Vacio Estancia
-- Asado
-- Zanahoria
-- Perejil
-- Ajo
-- Naranja jugo
-- Uva redglobe
-- Bife Americano (ERROR)
